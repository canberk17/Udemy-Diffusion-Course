# %%
import torch
import torch.nn as nn
import numpy as np
from tqdm import tqdm
from keras.datasets.mnist import load_data

from unet import UNet
from diffusionl import DiffusionModel
import matplotlib.pyplot as plt

# %%
(trainX, trainy), (testX, testy) = load_data()
trainX = np.float32(trainX) / 255.
testX = np.float32(testX) / 255.

def sample_batch(batch_size, device):
    indices = torch.randperm(trainX.shape[0])[:batch_size]
    data = torch.from_numpy(trainX[indices]).unsqueeze(1).to(device)
    return torch.nn.functional.interpolate(data, 32)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
device = 'cuda'
model = torch.load('model_paper2_epoch_39999').to(device)
diffusion_model = DiffusionModel(1000, model, device)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-61dec6ec88d6> in <cell line: 2>()
#       1 device = 'cuda'
# ----> 2 model = torch.load('model_paper2_epoch_39999').to(device)
#       3 diffusion_model = DiffusionModel(1000, model, device)
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     789         pickle_load_args['encoding'] = 'utf-8'
#     790
# --> 791     with _open_file_like(f, 'rb') as opened_file:
#     792         if _is_zipfile(opened_file):
#     793             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     250 class _open_file(_opener):
#     251     def __init__(self, name, mode):
# --> 252         super().__init__(open(name, mode))
#     253
#     254     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_paper2_epoch_39999'

# %%
def forward(diffusion_model, T, x0):

    x_forward = []
    x = x0
    for t in range(T):
        std = torch.sqrt(diffusion_model.beta[t])
        x = x + torch.randn_like(x) * std
        x_forward.append(x)
    return x_forward

# %%
@torch.no_grad()
def inpaining(self, x0, mask):

    # Run the forward process
    x = x0.clone()
    x_forward = [x]
    for t in range(self.T):
        std = torch.sqrt(diffusion_model.beta[t])
        x = torch.sqrt(1 - diffusion_model.beta[t]) * x + torch.randn_like(x) * std
        x_forward.append(x.clone())

    x = x_forward[-1]

    for t in tqdm(range(self.T, 0, -1)):
        z = torch.randn_like(x) if t > 1 else torch.zeros_like(x)

        t_tensor = torch.ones(x0.shape[0], dtype=torch.long, device=self.device) * t

        beta_t = self.beta[t-1].unsqueeze(-1).unsqueeze(-1).unsqueeze(-1)
        alpha_t = self.alpha[t-1].unsqueeze(-1).unsqueeze(-1).unsqueeze(-1)
        alpha_bar_t = self.alpha_bar[t-1].unsqueeze(-1).unsqueeze(-1).unsqueeze(-1)

        mean = 1 / torch.sqrt(alpha_t) * (x - ((1 - alpha_t) / torch.sqrt(
            1 - alpha_bar_t)) * self.function_approximator(x, t_tensor-1))
        sigma = torch.sqrt(beta_t)

        x = x_forward[t-1]
        x[mask] = (mean + sigma * z)[mask]

    return x

# %%
x0 = sample_batch(2, device)
mask = torch.zeros_like(x0).bool()
mask[:, :, :, :18] = 1.
x = inpaining(diffusion_model, x0, mask)
plt.imshow(x0[0, 0].data.cpu().numpy(), cmap='gray')
plt.show()
plt.imshow(x[0, 0].data.cpu().numpy(), cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-7de03d7fe03e> in <cell line: 1>()
# ----> 1 x0 = sample_batch(2, device)
#       2 mask = torch.zeros_like(x0).bool()
#       3 mask[:, :, :, :18] = 1.
#       4 x = inpaining(diffusion_model, x0, mask)
#       5 plt.imshow(x0[0, 0].data.cpu().numpy(), cmap='gray')
#
# <ipython-input-4-90357a437601> in sample_batch(batch_size, device)
#       5 def sample_batch(batch_size, device):
#       6     indices = torch.randperm(trainX.shape[0])[:batch_size]
# ----> 7     data = torch.from_numpy(trainX[indices]).unsqueeze(1).to(device)
#       8     return torch.nn.functional.interpolate(data, 32)
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     245         if 'CUDA_MODULE_LOADING' not in os.environ:
#     246             os.environ['CUDA_MODULE_LOADING'] = 'LAZY'
# --> 247         torch._C._cuda_init()
#     248         # Some of the queued calls may reentrantly call _lazy_init();
#     249         # we need to just return without initializing in that case.
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
x0 = sample_batch(2, device)
mask = torch.zeros_like(x0).bool()
mask[:, :, :, :18] = 1.
x = inpaining(diffusion_model, x0, mask)
plt.imshow(x0[0, 0].data.cpu().numpy(), cmap='gray')
plt.show()
plt.imshow(x[0, 0].data.cpu().numpy(), cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2fdb6096c98b> in <cell line: 1>()
# ----> 1 plt.imshow(x500[0].data.cpu().numpy(),cmap='gray')
#
# NameError: name 'x500' is not defined

# %%
x0 = sample_batch(2, device)
mask = torch.zeros_like(x0).bool()
mask[:, :, :, :18] = 1.
x = inpaining(diffusion_model, x0, mask)
plt.imshow(x0[0, 0].data.cpu().numpy(), cmap='gray')
plt.show()
plt.imshow(x[0, 0].data.cpu().numpy(), cmap='gray')
plt.show()

# %%
import tensorflow as tf
import tensorflow_hub as hub
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
print(tf.__version__)
print(hub.__version__)
# Out:
# 2.12.0
# 0.13.0

# %%
image = Image.open('istanbul.jpeg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x545 at 0x7FE2E4CB63E0>

# %%
image.size
# Out:
# (800, 545)
